# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

df= pd.read_csv("NYC11.csv")
df.head()

df.info()

df.describe()

df.isnull().sum()

df.fillna(0, inplace= True)

df.isnull().sum()

numerical_df = df.select_dtypes(include=['number'])

scaler = StandardScaler()

scaled_array = scaler.fit_transform(numerical_df)

scaled_df = pd.DataFrame(scaled_array, columns=numerical_df.columns)

print("Scaled DataFrame:")
print(scaled_df.head())

pca = PCA(n_components=0.95)
pca_components = pca.fit_transform(scaled_df)

print("\nExplained Variance Ratio:")
print(pca.explained_variance_ratio_)

df.dtypes                          
df.select_dtypes(include= 'object')

df.select_dtypes(include= 'number')

df['ZoneDist3'].value_counts()
#df.drop('ZoneDist3', axis=1)

df.hist(bins= 30, figsize= (15,10))
plt.tight_layout()

plt.figure(figsize= (10,8))
sns.heatmap(df.corr(numeric_only= True), annot= True, cmap='crest')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\HRISHITA\AppData\Local\Temp\ipykernel_13368\4052176778.py:8: DtypeWarning: Columns (19,20,22,23,24,25,26,64,65,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv("NYC11.csv")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277316 entries, 0 to 277315
# Data columns (total 87 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Borough               277316 non-null  object
#  1   Block                 277316 non-null  int64
#  2   Lot                   277316 non-null  int64
#  3   CD                    277316 non-null  int64
#  4   CT2010                276749 non-null  float64
#  5   CB2010                274792 non-null  float64
#  6   SchoolDist            277023 non-null  float64
#  7   Council               276925 non-null  float64
#  8   ZipCode               276681 non-null  float64
#  9   FireComp              276855 non-null  object
#  10  PolicePrct            276947 non-null  float64
#  11  HealthCenterDistrict  276991 non-null  float64
#  12  HealthArea            276821 non-null  float64
#  13  SanitBoro             276327 non-null  float64
#  14  SanitDistrict         276333 non-null  float64
#  15  SanitSub              272098 non-null  object
#  16  Address               277133 non-null  object
#  17  ZoneDist1             277150 non-null  object
#  18  ZoneDist2             7204 non-null    object
#  19  ZoneDist3             78 non-null      object
#  20  ZoneDist4             6 non-null       object
#  21  Overlay1              35535 non-null   object
#  22  Overlay2              56 non-null      object
#  23  SPDist1               28155 non-null   object
#  24  SPDist2               19 non-null      object
#  25  SPDist3               1 non-null       object
#  26  LtdHeight             2192 non-null    object
#  27  SplitZone             277142 non-null  object
#  28  BldgClass             277142 non-null  object
#  29  LandUse               275944 non-null  float64
#  30  Easements             277316 non-null  int64
#  31  OwnerType             41158 non-null   object
#  32  OwnerName             273110 non-null  object
#  33  LotArea               277316 non-null  int64
#  34  BldgArea              277316 non-null  int64
#  35  ComArea               277316 non-null  int64
#  36  ResArea               277316 non-null  int64
#  37  OfficeArea            277316 non-null  int64
#  38  RetailArea            277316 non-null  int64
#  39  GarageArea            277316 non-null  int64
#  40  StrgeArea             277316 non-null  int64
#  41  FactryArea            277316 non-null  int64
#  42  OtherArea             277316 non-null  int64
#  43  AreaSource            277316 non-null  int64
#  44  NumBldgs              277316 non-null  int64
#  45  NumFloors             277316 non-null  float64
#  46  UnitsRes              277316 non-null  int64
#  47  UnitsTotal            277316 non-null  int64
#  48  LotFront              277316 non-null  float64
#  49  LotDepth              277316 non-null  float64
#  50  BldgFront             277316 non-null  float64
#  51  BldgDepth             277316 non-null  float64
#  52  Ext                   70910 non-null   object
#  53  ProxCode              277142 non-null  float64
#  54  IrrLotCode            277142 non-null  object
#  55  LotType               277142 non-null  float64
#  56  BsmtCode              277142 non-null  float64
#  57  AssessLand            277316 non-null  int64
#  58  AssessTot             277316 non-null  int64
#  59  ExemptLand            277316 non-null  int64
#  60  ExemptTot             277316 non-null  int64
#  61  YearBuilt             277316 non-null  int64
#  62  YearAlter1            277316 non-null  int64
#  63  YearAlter2            277316 non-null  int64
#  64  HistDist              13894 non-null   object
#  65  Landmark              213 non-null     object
#  66  BuiltFAR              277316 non-null  float64
#  67  ResidFAR              277316 non-null  float64
#  68  CommFAR               277316 non-null  float64
#  69  FacilFAR              277316 non-null  float64
#  70  BoroCode              277316 non-null  int64
#  71  BBL                   277316 non-null  int64
#  72  CondoNo               277316 non-null  int64
#  73  Tract2010             277316 non-null  int64
#  74  XCoord                273933 non-null  float64
#  75  YCoord                273933 non-null  float64
#  76  ZoneMap               277292 non-null  object
#  77  ZMCode                4530 non-null    object
#  78  Sanborn               276753 non-null  object
#  79  TaxMap                276753 non-null  float64
#  80  EDesigNum             3207 non-null    object
#  81  APPBBL                277142 non-null  float64
#  82  APPDate               20905 non-null   object
#  83  PLUTOMapID            277316 non-null  int64
#  84  FIRM07_FLAG           7469 non-null    float64
#  85  PFIRM15_FLAG          25226 non-null   float64
#  86  Version               277316 non-null  object
# dtypes: float64(29), int64(30), object(28)
# memory usage: 184.1+ MB
# Scaled DataFrame:
#       Block       Lot        CD    CT2010    CB2010  SchoolDist   Council  \
# 0 -1.878036 -0.179579 -1.524325 -1.475416 -1.947487   -1.553095 -1.722546
# 1 -1.878036 -0.125090 -1.524325 -1.475416  0.061200   -1.553095 -1.722546
# 2 -1.878036  8.160573 -1.524325 -1.475416  0.061200   -1.553095 -1.722546
# 3 -1.877247 -0.179579 -1.524325 -1.475416  1.067552   -1.553095 -1.722546
# 4 -1.877247 -0.175131 -1.524325 -1.475416 -1.947487   -1.553095 -1.722546
#
#     ZipCode  PolicePrct  HealthCenterDistrict  ...       BBL    CondoNo  \
# 0  0.011703    1.454058              0.577474  ... -1.878046  -0.103795
# 1  0.011703    1.454058              0.577474  ... -1.878044  -0.103795
# 2  0.011703    1.454058              0.577474  ... -1.877750  13.235337
# 3  0.011703    1.454058              0.577474  ... -1.877256  -0.103795
# 4  0.011703    1.454058              0.577474  ... -1.877256  -0.103795
#
#    Tract2010    XCoord    YCoord    TaxMap    APPBBL  PLUTOMapID  FIRM07_FLAG  \
# 0  -0.252206 -8.955206 -7.479358 -0.683943  3.453927   -0.048991     6.010735
# 1  -0.252206  0.024738  0.998010 -0.683943 -0.285525   -0.048991     6.010735
# 2  -0.252206  0.022792  0.998139 -0.683943  3.453927   -0.048991     6.010735
# 3  -0.252206  0.031374  1.005017 -0.683943 -0.285525   -0.048991     6.010735
# 4  -0.252206 -8.955206 -7.479358 -0.683943 -0.285525   40.790813     6.010735
#
#    PFIRM15_FLAG
# 0      3.161212
# 1      3.161212
# 2      3.161212
# 3      3.161212
# 4      3.161212
#
# [5 rows x 59 columns]
#
# Explained Variance Ratio:
# [0.12816331 0.07652534 0.07226106 0.06245374 0.05242933 0.04208912
#  0.03950385 0.03204641 0.02827699 0.02614458 0.02423768 0.02245145
#  0.02169332 0.02062378 0.01971032 0.01795106 0.01748397 0.01723826
#  0.01716327 0.01696497 0.01562505 0.01557185 0.014787   0.01413692
#  0.01310524 0.01242414 0.01193383 0.01153015 0.01135969 0.0108198
#  0.01041344 0.0102282  0.00985579 0.00895082 0.00817232 0.00805791
#  0.00794821]
# C:\Users\HRISHITA\anaconda3\envs\TF\lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
